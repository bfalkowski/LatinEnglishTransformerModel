# %%
#!pip install torchtext
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (0.11.4)
# Requirement already satisfied: torch>=1.8.1 in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from torchmetrics) (2.0.1)
# Requirement already satisfied: numpy>=1.17.2 in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from torchmetrics) (1.23.5)
# Requirement already satisfied: packaging in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from torchmetrics) (22.0)
# Requirement already satisfied: typing-extensions in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from torchmetrics) (3.7.4.3)
# Requirement already satisfied: filelock in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.8.1->torchmetrics) (3.0.12)
# Requirement already satisfied: networkx in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.8.1->torchmetrics) (2.5)
# Requirement already satisfied: sympy in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.8.1->torchmetrics) (1.6.2)
# Requirement already satisfied: jinja2 in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.8.1->torchmetrics) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from jinja2->torch>=1.8.1->torchmetrics) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from networkx->torch>=1.8.1->torchmetrics) (4.4.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages (from sympy->torch>=1.8.1->torchmetrics) (1.1.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 30

from train import train_model

train_model(cfg)
# Out:
# /Users/bryanfalkowski/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Using device: cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-edbf36bf7593> in <module>
#       7 from train import train_model
#       8
# ----> 9 train_model(cfg)
#
# ~/Documents/repo/pytorch-transformer-eng-latin v1/train.py in train_model(config)
#     186     Path(config['model_folder']).mkdir(parents=True, exist_ok=True)
#     187
# --> 188     train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
#     189     model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)
#     190     # Tensorboard
#
# ~/Documents/repo/pytorch-transformer-eng-latin v1/train.py in get_ds(config)
#     141 def get_ds(config):
#     142     # It only has the train split, so we divide it overselves
# --> 143     ds_raw = load_dataset('opus_books', f"{config['lang_src']}-{config['lang_tgt']}", split='train')
#     144
#     145     # Build tokenizers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, script_version, **config_kwargs)
#    1625
#    1626     # Create a dataset builder
# -> 1627     builder_instance = load_dataset_builder(
#    1628         path=path,
#    1629         name=name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/datasets/load.py in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, use_auth_token, script_version, **config_kwargs)
#    1483
#    1484     # Instantiate the dataset builder
# -> 1485     builder_instance: DatasetBuilder = builder_cls(
#    1486         cache_dir=cache_dir,
#    1487         name=name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/datasets/builder.py in __init__(self, writer_batch_size, *args, **kwargs)
#    1018
#    1019     def __init__(self, *args, writer_batch_size=None, **kwargs):
# -> 1020         super(GeneratorBasedBuilder, self).__init__(*args, **kwargs)
#    1021         # Batch size used by the ArrowWriter
#    1022         # It defines the number of samples that are kept in memory before writing them
#
# ~/opt/anaconda3/lib/python3.8/site-packages/datasets/builder.py in __init__(self, cache_dir, name, hash, base_path, features, use_auth_token, namespace, data_files, data_dir, **config_kwargs)
#     256         if data_dir is not None:
#     257             config_kwargs["data_dir"] = data_dir
# --> 258         self.config, self.config_id = self._create_builder_config(
#     259             name,
#     260             custom_features=features,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/datasets/builder.py in _create_builder_config(self, name, custom_features, **config_kwargs)
#     346             builder_config = self.builder_configs.get(name)
#     347             if builder_config is None and self.BUILDER_CONFIGS:
# --> 348                 raise ValueError(f"BuilderConfig {name} not found. Available: {list(self.builder_configs.keys())}")
#     349
#     350         # if not using an existing config, then create a new config on the fly with config_kwargs
#
# ValueError: BuilderConfig en-la not found. Available: ['ca-de', 'ca-en', 'de-en', 'el-en', 'de-eo', 'en-eo', 'de-es', 'el-es', 'en-es', 'eo-es', 'en-fi', 'es-fi', 'de-fr', 'el-fr', 'en-fr', 'eo-fr', 'es-fr', 'fi-fr', 'ca-hu', 'de-hu', 'el-hu', 'en-hu', 'eo-hu', 'fr-hu', 'de-it', 'en-it', 'eo-it', 'es-it', 'fr-it', 'hu-it', 'ca-nl', 'de-nl', 'en-nl', 'es-nl', 'fr-nl', 'hu-nl', 'it-nl', 'en-no', 'es-no', 'fi-no', 'fr-no', 'hu-no', 'en-pl', 'fi-pl', 'fr-pl', 'hu-pl', 'de-pt', 'en-pt', 'eo-pt', 'es-pt', 'fr-pt', 'hu-pt', 'it-pt', 'de-ru', 'en-ru', 'es-ru', 'fr-ru', 'hu-ru', 'it-ru', 'en-sv', 'fr-sv', 'it-sv']
